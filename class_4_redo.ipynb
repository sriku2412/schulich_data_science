# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv(r"C:\Users\srika\OneDrive\Documents\York\Sem-1 york\MBAN 6110 - Data Science 1\new_data.csv\new_data.csv",index_col='Unnamed: 0')
print(df.columns)
# Out:
# Index(['event_time', 'event_type', 'product_id', 'category_id',
#        'category_code', 'brand', 'price', 'user_id', 'user_session'],
#       dtype='object')

# %%
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-11-01 00:00:00 UTC       view     1003461  2053013555631882655
# 1  2019-11-01 00:00:00 UTC       view     5000088  2053013566100866035
# 2  2019-11-01 00:00:01 UTC       view    17302664  2053013553853497655
# 3  2019-11-01 00:00:01 UTC       view     3601530  2053013563810775923
# 4  2019-11-01 00:00:01 UTC       view     1004775  2053013555631882655
#
#                category_code   brand   price    user_id  \
# 0     electronics.smartphone  xiaomi  489.07  520088904
# 1  appliances.sewing_machine  janome  293.65  530496790
# 2                        NaN   creed   28.31  561587266
# 3  appliances.kitchen.washer      lg  712.87  518085591
# 4     electronics.smartphone  xiaomi  183.27  558856683
#
#                            user_session
# 0  4d3b30da-a5e4-49df-b1a8-ba5943f1dd33
# 1  8e5f4f83-366c-4f70-860e-ca7417414283
# 2  755422e7-9040-477b-9bd2-6a6e8fd97387
# ...

# %%
print(df.shape)
df.describe(include='all')
# Out:
# (10000000, 9)
#                      event_time event_type    product_id   category_id  \
# count                  10000000   10000000  1.000000e+07  1.000000e+07
# unique                   523423          3           NaN           NaN
# top     2019-11-05 17:23:19 UTC       view           NaN           NaN
# freq                        113    9731128           NaN           NaN
# mean                        NaN        NaN  1.100008e+07  2.057828e+18
# std                         NaN        NaN  1.228346e+07  1.943274e+16
# min                         NaN        NaN  1.000365e+06  2.053014e+18
# 25%                         NaN        NaN  1.005252e+06  2.053014e+18
# 50%                         NaN        NaN  5.100722e+06  2.053014e+18
# 75%                         NaN        NaN  1.640001e+07  2.053014e+18
# max                         NaN        NaN  6.210003e+07  2.180737e+18
#
#                  category_code    brand         price       user_id  \
# ...

# %%
df.isnull().sum()
# Out:
# event_time             0
# event_type             0
# product_id             0
# category_id            0
# category_code    3302790
# brand            1410463
# price                  0
# user_id                0
# user_session           0
# dtype: int64

# %%
# we need to match catigory ID with catigory code
df[df['category_code'].isnull()].fillna(df['category_code'],inplace=True,)

# %%
df.isnull().sum()
# Out:
# event_time             0
# event_type             0
# product_id             0
# category_id            0
# category_code    3302790
# brand            1410463
# price                  0
# user_id                0
# user_session           0
# dtype: int64

# %%
dfs=df[['category_code','category_id']]
dfs=dfs.drop_duplicates()
dfs.dropna(inplace=True)
print(dfs.shape)
dfs.head()
dfd=df[['category_code','product_id']]
dfd=dfd.drop_duplicates()
dfd.dropna(inplace=True)
print(dfd.shape)
dfd.head()
# Out:
# (252, 2)
# (60956, 2)
#                category_code  product_id
# 0     electronics.smartphone     1003461
# 1  appliances.sewing_machine     5000088
# 3  appliances.kitchen.washer     3601530
# 4     electronics.smartphone     1004775
# 5         computers.notebook     1306894

# %%
df.fillna(dfs, inplace=True)
df.fillna(dfd, inplace=True)
df.isnull().sum()
# Out:
# event_time             0
# event_type             0
# product_id             0
# category_id            0
# category_code    3302790
# brand            1410463
# price                  0
# user_id                0
# user_session           0
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 ddfs=df['event_time'].count().unstack()
#       2 ddfs
#
# AttributeError: 'numpy.int64' object has no attribute 'unstack'
