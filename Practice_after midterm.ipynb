# %%
import pandas as pd 
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\srika\OneDrive\Documents\York\Sem-1 york\MBAN 6110 - Data Science 1\messy_data.csv")
df.describe(include='all')
df.reset_index()
# Out:
#      index  Age       Income  Gender Product  Quantity
# 0        0   56  59544.57663  Female       D         3
# 1        1   46  36399.18997  Female     NaN         1
# 2        2   32  57140.63881  Female       D         2
# 3        3   60  69554.91903    Male       C         5
# 4        4   25  53173.80518  Female       D         2
# ..     ...  ...          ...     ...     ...       ...
# 100    100   61  37341.55459    Male       D         5
# 101    101   55  35516.63492  Female       A         3
# 102    102   31  53254.05089    Male       B         2
# 103    103   21          NaN    Male       B         2
# 104    104   60  69554.91903    Male       C         5
#
# [105 rows x 6 columns]

# %%
sns.scatterplot(data=df,x='Age',y='Income')
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
df.drop(df[df['Age']>=80].index,axis=0,inplace=True)
sns.scatterplot(data=df,x='Age',y='Income')
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
df.drop(df[df['Income']>=150000].index,axis=0,inplace=True)
sns.scatterplot(data=df,x='Age',y='Income')
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
sns.scatterplot(data=df,x='Age',y='Income',hue='Gender',size='Product')
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
sns.boxplot(data=df,x='Gender',y='Age')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(data=df,x='Gender',y='Income')
# Out:
# <Axes: xlabel='Gender', ylabel='Income'>

# %%
df.drop(df[(df['Gender']=='Female') & (df['Income']>=91000)].index,axis=0, inplace=True)

# %%
sns.boxplot(data=df,x='Gender',y='Income')
# Out:
# <Axes: xlabel='Gender', ylabel='Income'>

# %%
sns.scatterplot(data=df[df['Gender']=='Female'],x='Age',y='Income',hue='Product')
# Out:
# <Axes: xlabel='Age', ylabel='Income'>

# %%
sns.scatterplot(data=df,x='Product',y='Quantity')
# Out:
# <Axes: xlabel='Product', ylabel='Quantity'>

# %%
df[df['Product']=='A'].count()
# Out:
# Age         23
# Income      20
# Gender      23
# Product     23
# Quantity    23
# dtype: int64

# %%
df[df['Product']=='B'].count()
# Out:
# Age         24
# Income      19
# Gender      24
# Product     24
# Quantity    24
# dtype: int64

# %%
df.corr()
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_2916\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                Age    Income  Quantity
# Age       1.000000 -0.028946  0.016253
# Income   -0.028946  1.000000 -0.104123
# Quantity  0.016253 -0.104123  1.000000

# %%
df=pd.read_csv(r"C:\Users\srika\OneDrive\Documents\York\Sem-1 york\MBAN 6110 - Data Science 1\midterm_data.csv",index_col='userID')
df.head(5)
# Out:
#         age  sessions  time_spent  pages_visited  cart_items  cart_value  \
# userID
# 1        62         3   13.295129              2          20      199.21
# 2        65         2   21.686405              3          21      294.82
# 3        18         7   17.135220              4          23      240.87
# 4        21         9   29.589311              8          16      183.78
# 5        21         3   25.948584              4          10       59.51
#
#         checkout_status   device    location
# userID
# 1                     0  Desktop  Location 1
# 2                     0  Desktop  Location 3
# 3                     0  Desktop  Location 4
# 4                     1  Desktop  Location 2
# 5                     1   Tablet  Location 4

# %%
df.corr()
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_2916\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                       age  sessions  time_spent  pages_visited  cart_items  \
# age              1.000000  0.017823   -0.018623      -0.021820   -0.002737
# sessions         0.017823  1.000000   -0.016158      -0.006726   -0.021743
# time_spent      -0.018623 -0.016158    1.000000       0.911949   -0.007016
# pages_visited   -0.021820 -0.006726    0.911949       1.000000   -0.008775
# cart_items      -0.002737 -0.021743   -0.007016      -0.008775    1.000000
# cart_value      -0.003171 -0.026117   -0.002688      -0.007170    0.877345
# checkout_status -0.009247 -0.019919    0.383605       0.360232   -0.085620
#
#                  cart_value  checkout_status
# ...

# %%
sns.pairplot(df)

# %%
df.drop(df[df['time_spent']>=60].index, axis=0, inplace=True)
sns.scatterplot(data=df,x='time_spent',y='checkout_status')
# Out:
# <Axes: xlabel='time_spent', ylabel='checkout_status'>

# %%
df.drop(df[df['time_spent']==0].index,axis=0,inplace=True)
sns.boxplot(data=df,x='age',y='time_spent')
# Out:
# <Axes: xlabel='age', ylabel='time_spent'>

# %%
df.drop(df[df['time_spent']<=1].index,axis=0,inplace=True)
sns.scatterplot(data=df,x='cart_value',y='time_spent')
# Out:
# <Axes: xlabel='cart_value', ylabel='time_spent'>

# %%
df.head(5)
# df['revenue']=df['cart_items']+df['cart_value']
df['age'].describe()
sns.boxplot(data=df, x='age',y='device')
# Out:
# <Axes: xlabel='age', ylabel='device'>

# %%
df.head()
sns.histplot(df['time_spent'])
# Out:
# <Axes: xlabel='time_spent', ylabel='Count'>

# %%
df.head()
# Out:
#         age  sessions  time_spent  pages_visited  cart_items  cart_value  \
# userID
# 1        62         3   13.295129              2          20      199.21
# 2        65         2   21.686405              3          21      294.82
# 3        18         7   17.135220              4          23      240.87
# 4        21         9   29.589311              8          16      183.78
# 5        21         3   25.948584              4          10       59.51
#
#         checkout_status   device    location  revenue
# userID
# 1                     0  Desktop  Location 1   219.21
# 2                     0  Desktop  Location 3   315.82
# 3                     0  Desktop  Location 4   263.87
# 4                     1  Desktop  Location 2   199.78
# 5                     1   Tablet  Location 4    69.51

# %%
df=pd.read_csv(r"C:\Users\srika\OneDrive\Documents\York\Sem-1 york\MBAN 6110 - Data Science 1\midterm_data.csv",index_col='userID')
df.head(5)
# Out:
#         age  sessions  time_spent  pages_visited  cart_items  cart_value  \
# userID
# 1        62         3   13.295129              2          20      199.21
# 2        65         2   21.686405              3          21      294.82
# 3        18         7   17.135220              4          23      240.87
# 4        21         9   29.589311              8          16      183.78
# 5        21         3   25.948584              4          10       59.51
#
#         checkout_status   device    location
# userID
# 1                     0  Desktop  Location 1
# 2                     0  Desktop  Location 3
# 3                     0  Desktop  Location 4
# 4                     1  Desktop  Location 2
# 5                     1   Tablet  Location 4

# %%
df = pd.read_csv(r"C:\Users\srika\OneDrive\Documents\York\Sem-1 york\MBAN 6110 - Data Science 1\messy_data.csv")
df.describe(include='all')
df.reset_index()
# Out:
#      index  Age       Income  Gender Product  Quantity
# 0        0   56  59544.57663  Female       D         3
# 1        1   46  36399.18997  Female     NaN         1
# 2        2   32  57140.63881  Female       D         2
# 3        3   60  69554.91903    Male       C         5
# 4        4   25  53173.80518  Female       D         2
# ..     ...  ...          ...     ...     ...       ...
# 100    100   61  37341.55459    Male       D         5
# 101    101   55  35516.63492  Female       A         3
# 102    102   31  53254.05089    Male       B         2
# 103    103   21          NaN    Male       B         2
# 104    104   60  69554.91903    Male       C         5
#
# [105 rows x 6 columns]

# %%
df.drop(df[df['Income']>=150000].index,axis=0,inplace=True)
df.drop(df[(df['Gender']=='Female') & (df['Income']>=91000)].index,axis=0, inplace=True)
sns.boxplot(data=df,x='Gender',y='Income')
plt.show()
sns.set_style('whitegrid')
sns.kdeplot(data=df, x='Income', hue='Gender', fill=True)
sns.despine()
plt.show()

# %%
sns.set_style('whitegrid')
sns.kdeplot(data=df, x='Income', hue='Gender', fill=True)
sns.despine()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.set_style('whitegrid')
#       2 sns.kdeplot(data=df, x='Income', hue='Gender', fill=True)
#       3 sns.despine()
#
# NameError: name 'sns' is not defined

# %%
df.head()
# Out:
#    Age       Income  Gender Product  Quantity
# 0   56  59544.57663  Female       D         3
# 1   46  36399.18997  Female     NaN         1
# 2   32  57140.63881  Female       D         2
# 3   60  69554.91903    Male       C         5
# 4   25  53173.80518  Female       D         2

# %%
df.drop(df[df['Age']>=100].index,axis=0,inplace=True)
sns.set_style('whitegrid')
sns.kdeplot(data=df, x = 'Age', hue = 'Gender', fill = True)
sns.despine()
plt.show()

# %%
df.head(5)
df.groupby(['Gender','Product'],as_index=False)[['Income','Age']].agg(['mean','sum','max','min','median','count'])
# Out:
#                       Income                                          \
#                         mean           sum          max          min
# Gender Product
# Female A        49175.734426  442581.60983  74343.80749  32043.69405
#        B        46910.896754  656752.55455  64439.61935  30171.84574
#        C        54348.631902  543486.31902  89502.92331  27763.63630
#        D        48042.840773  768685.45237  66300.90535  28602.81673
# Male   A        53847.896539  592326.86193  79618.56795  24735.68932
#        B        54596.412250  272982.06125  79475.52146  39195.53011
#        C        49304.516668  591654.20001  69554.91903  20901.33172
#        D        48216.163493  433945.47144  72034.11928  33548.71552
#
#                                           Age
#                       median count       mean  sum max min median count
# Gender Product
# Female A        48320.182690     9  44.090909  485  61  19   41.0    11
# ...

# %%
df.drop_duplicates()
# Out:
#     Age       Income  Gender Product  Quantity
# 0    56  59544.57663  Female       D         3
# 1    46  36399.18997  Female     NaN         1
# 2    32  57140.63881  Female       D         2
# 3    60  69554.91903    Male       C         5
# 4    25  53173.80518  Female       D         2
# ..  ...          ...     ...     ...       ...
# 93   18  50984.73737  Female       D         1
# 94   42  67538.11470    Male     NaN         1
# 95   24  63099.75454  Female       B         5
# 96   26  53084.75201    Male       D         3
# 97   41  28347.74972    Male       C         3
#
# [97 rows x 5 columns]

# %%
df.describe(include='all')
# Out:
#                Age        Income  Gender Product    Quantity
# count   102.000000     91.000000     102      97  102.000000
# unique         NaN           NaN       2       4         NaN
# top            NaN           NaN  Female       D         NaN
# freq           NaN           NaN      56      27         NaN
# mean     41.176471  49899.338633     NaN     NaN    3.156863
# std      14.032785  14609.281411     NaN     NaN    1.440195
# min      18.000000  20901.331720     NaN     NaN    1.000000
# 25%      31.000000  37965.971040     NaN     NaN    2.000000
# 50%      41.000000  48737.523720     NaN     NaN    3.000000
# 75%      54.750000  60293.205945     NaN     NaN    4.000000
# max      64.000000  89502.923310     NaN     NaN    5.000000

# %%
df.head()
df['Age_bins'] = pd.cut(df['Age'],bins=3,labels=('young','middle_age','old'))

# %%
df.head()
# Out:
#    Age       Income  Gender Product  Quantity    Age_bins
# 0   56  59544.57663  Female       D         3         old
# 1   46  36399.18997  Female     NaN         1  middle_age
# 2   32  57140.63881  Female       D         2       young
# 3   60  69554.91903    Male       C         5         old
# 4   25  53173.80518  Female       D         2       young

# %%
dc = df.groupby(['Age_bins','Gender'], as_index = False)['Income'].agg(['mean','min','max'])
dc
# Out:
#                            mean          min          max
# Age_bins   Gender
# young      Female  46567.065421  27763.63630  64439.61935
#            Male    52558.699954  30330.13661  71019.82347
# middle_age Female  49662.115484  33556.01307  84308.38974
#            Male    56988.282945  28347.74972  79618.56795
# old        Female  51321.797894  30171.84574  89502.92331
#            Male    41937.350193  20901.33172  69554.91903

# %%
sns.scatterplot(data=dc,x='Age_bins',y='Gender',size='max')
# Out:
# <Axes: xlabel='Age_bins', ylabel='Gender'>

# %%
df.describe(include='all')
# Out:
#                Age        Income  Gender Product    Quantity Age_bins
# count   102.000000     91.000000     102      97  102.000000      102
# unique         NaN           NaN       2       4         NaN        3
# top            NaN           NaN  Female       D         NaN    young
# freq           NaN           NaN      56      27         NaN       36
# mean     41.176471  49899.338633     NaN     NaN    3.156863      NaN
# std      14.032785  14609.281411     NaN     NaN    1.440195      NaN
# min      18.000000  20901.331720     NaN     NaN    1.000000      NaN
# 25%      31.000000  37965.971040     NaN     NaN    2.000000      NaN
# 50%      41.000000  48737.523720     NaN     NaN    3.000000      NaN
# 75%      54.750000  60293.205945     NaN     NaN    4.000000      NaN
# max      64.000000  89502.923310     NaN     NaN    5.000000      NaN

# %%
df['Product'].fillna(method='ffill')
# Out:
# 0      D
# 1      D
# 2      D
# 3      C
# 4      D
#       ..
# 100    D
# 101    A
# 102    B
# 103    B
# 104    C
# Name: Product, Length: 102, dtype: object
