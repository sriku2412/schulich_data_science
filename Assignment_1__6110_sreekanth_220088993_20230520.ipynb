# %% [markdown]
# # Assignment 1: Descriptive Statistics and Probability Theory

# %% [markdown]
# **Importing libraries to read the sales document**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sales = pd.read_csv(r"C:\Users\srika\OneDrive\Documents\York\Sem-1 york\MBAN 6110 - Data Science 1\Assignment 1\sales_data.csv")
sales.describe(include='all')
# Out:
#            Product    Region        Price  Units Sold   Sale Date
# count          947       946   945.000000  946.000000        1050
# unique          50        10          NaN         NaN        1000
# top     Product_45  Region_9          NaN         NaN  2022-07-28
# freq            28       109          NaN         NaN           2
# mean           NaN       NaN   107.598688   10.048626         NaN
# std            NaN       NaN   124.020322    3.172261         NaN
# min            NaN       NaN     0.200000    2.000000         NaN
# 25%            NaN       NaN    29.430000    8.000000         NaN
# 50%            NaN       NaN    78.130000   10.000000         NaN
# 75%            NaN       NaN   142.570000   12.000000         NaN
# max            NaN       NaN  2143.300000   22.000000         NaN

# %% [markdown]
# **From the above, we can see for the 'units sold' the mean  and 50% are very near. Hence we can use the data for further analysis.**

# %%
sns.histplot(sales['Units Sold'],color='green',bins=40)
# Out:
# <Axes: xlabel='Units Sold', ylabel='Count'>

# %% [markdown]
# The distribution looks fairly normal

# %%
sns.boxplot(sales['Units Sold'])
# Out:
# <Axes: >

# %% [markdown]
# from the baove we can see 3 out liers whcih can be removed for improving the reulst of the analysis

# %% [markdown]
# finding the total revenue

# %%
sales.drop([221,232,719,912,962],axis=0,inplace=True)

# %%
sns.boxplot(sales['Units Sold'])
# Out:
# <Axes: >

# %%
sns.histplot(sales['Units Sold'])
# Out:
# <Axes: xlabel='Units Sold', ylabel='Count'>

# %%
sns.boxplot(sales['Price'])
# Out:
# <Axes: >

# %% [markdown]
# there is one price that is very high. removing this data point would improve the values.

# %%
sns.scatterplot(data = sales, x = 'Price', y = 'Units Sold')
# Out:
# <Axes: xlabel='Price', ylabel='Units Sold'>

# %%
sales.drop(sales[sales['Price']==max].index,axis=0,inplace=True)

# %%
sns.scatterplot(data = sales, x = 'Price', y = 'Units Sold')
# Out:
# <Axes: xlabel='Price', ylabel='Units Sold'>

# %%
print(max(sales.Price))
# Out:
# 2143.3

# %%
sales.drop(sales[sales['Price']==2143.3].index,axis=0,inplace=True)

# %%
sns.scatterplot( x = 'Price', y = 'Units Sold',hue='sales', data = sales)
plt.plot([150, 0], [0, 20])

# %%
sns.boxplot(sales['Price'])
# Out:
# <Axes: >

# %%
sales.drop_duplicates(inplace=True)

# %%
sales['sales'] = sales['Price']*sales['Units Sold']

# %%
sales.head()
# Out:
#       Product    Region   Price  Units Sold   Sale Date    sales
# 0         NaN  Region_6   75.96        10.0  2022-01-01   759.60
# 1         NaN  Region_1  175.78         8.0  2022-01-02  1406.24
# 2  Product_46  Region_3   20.43        12.0  2022-01-03   245.16
# 3  Product_36  Region_1   12.77        10.0  2022-01-04   127.70
# 4  Product_17  Region_6  125.69         6.0  2022-01-05   754.14

# %%
sns.histplot(sales['sales'])
# Out:
# <Axes: xlabel='sales', ylabel='Count'>

# %% [markdown]
# higher revenue is observed with

# %%
sns.lmplot(data = sales, x = 'Price', y = 'sales',fit_reg=True,ci=99)

# %%
sns.lmplot(data = sales, x = 'Units Sold', y = 'sales', hue='Product')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 sns.lmplot(data = sales, x = 'Units Sold', y = 'sales', hue='Product')
#
# File c:\Users\srika\anaconda3\lib\site-packages\seaborn\regression.py:595, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     593 need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     594 cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 595 data = data[cols]
#     597 # Initialize the grid
#     598 facets = FacetGrid(
#     599     data, row=row, col=col, hue=hue,
#     600     palette=palette,
#    (...)
#     603     **facet_kws,
#     604 )
#
# File c:\Users\srika\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\srika\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\Users\srika\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['sales'] not in index"

# %% [markdown]
# # Drop duplicates

# %%
sales.drop_duplicates(inplace=True)
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     894 non-null    object
#  1   Region      894 non-null    object
#  2   Price       895 non-null    float64
#  3   Units Sold  894 non-null    float64
#  4   Sale Date   994 non-null    object
#  5   sales       804 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 54.4+ KB

# %%
sns.pairplot(sales)

# %%
sns.boxplot(sales)
# Out:
# <Axes: >

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 994 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     894 non-null    object
#  1   Region      894 non-null    object
#  2   Price       895 non-null    float64
#  3   Units Sold  894 non-null    float64
#  4   Sale Date   994 non-null    object
#  5   sales       804 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 54.4+ KB

# %% [markdown]
# # filling missing values

# %%
sales['Region']=sales['Region'].fillna('Other')
sales['Product']=sales['Product'].fillna('Other')
sales['Sale Date']=sales['Sale Date'].fillna('Other')
sales['Price']=sales['Price'].fillna(0)
sales['Units Sold']=sales['Units Sold'].fillna(0)
sales['sales'] = sales['Price']*sales['Units Sold']
sales.drop(sales[sales['Units Sold']==0].index,axis=0,inplace=True)
sales.drop(sales[sales['Price']==0].index,axis=0,inplace=True)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     804 non-null    object
#  1   Region      804 non-null    object
#  2   Price       804 non-null    float64
#  3   Units Sold  804 non-null    float64
#  4   Sale Date   804 non-null    object
#  5   sales       804 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 44.0+ KB

# %%
sales.drop_duplicates(inplace=True)
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     804 non-null    object
#  1   Region      804 non-null    object
#  2   Price       804 non-null    float64
#  3   Units Sold  804 non-null    float64
#  4   Sale Date   804 non-null    object
#  5   sales       804 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 44.0+ KB

# %%
sns.pairplot(sales)

# %%
sns.regplot(data = sales, x = 'sales', y = 'Units Sold',fit_reg=True,ci=100)
# Out:
# <Axes: xlabel='sales', ylabel='Units Sold'>

# %% [markdown]
# low units selling & products with low earning must be removed

# %%
sales[(sales['Units Sold']<=3) & (sales['sales']<=1000)]
# Out:
#         Product    Region   Price  Units Sold   Sale Date   sales
# 124  Product_37  Region_5  100.65         3.0  2022-05-05  301.95
# 237  Product_13  Region_5  129.81         2.0  2022-08-26  259.62
# 246       Other  Region_2  223.00         3.0  2022-09-04  669.00
# 315   Product_5  Region_3  264.72         2.0  2022-11-12  529.44
# 397  Product_10  Region_9    0.33         3.0  2023-02-02    0.99
# 447   Product_3  Region_3   15.05         3.0  2023-03-24   45.15
# 474  Product_23     Other  173.06         3.0  2023-04-20  519.18
# 560  Product_33  Region_7   88.69         3.0  2023-07-15  266.07
# 581   Product_5  Region_2  115.58         2.0  2023-08-05  231.16
# 660  Product_31  Region_5   58.05         3.0  2023-10-23  174.15
# 706       Other  Region_3  255.40         3.0  2023-12-08  766.20
# 844  Product_41  Region_3  139.33         2.0  2024-04-24  278.66
# 876   Product_6  Region_1   15.33         2.0  2024-05-26   30.66

# %%
sales.drop(sales.index[(sales['Units Sold']<=3) & (sales['sales']<=1000)], axis=0, inplace=True)

# %%
rs = sales.groupby('Product')['sales'].mean()
# Out:
# <Axes: >

# %% [markdown]
# some of the products are sold in high volume but have wery low income. we can remove low income volume.
