# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv(r"C:\Users\srika\OneDrive\Documents\York\Sem-1 york\MBAN 6110 - Data Science 1\new_data.csv\new_data.csv")
df.head(10)
# Out:
#    Unnamed: 0               event_time event_type  product_id  \
# 0           0  2019-11-01 00:00:00 UTC       view     1003461
# 1           1  2019-11-01 00:00:00 UTC       view     5000088
# 2           2  2019-11-01 00:00:01 UTC       view    17302664
# 3           3  2019-11-01 00:00:01 UTC       view     3601530
# 4           4  2019-11-01 00:00:01 UTC       view     1004775
# 5           5  2019-11-01 00:00:01 UTC       view     1306894
# 6           6  2019-11-01 00:00:01 UTC       view     1306421
# 7           7  2019-11-01 00:00:02 UTC       view    15900065
# 8           8  2019-11-01 00:00:02 UTC       view    12708937
# 9           9  2019-11-01 00:00:02 UTC       view     1004258
#
#            category_id              category_code     brand   price  \
# 0  2053013555631882655     electronics.smartphone    xiaomi  489.07
# 1  2053013566100866035  appliances.sewing_machine    janome  293.65
# 2  2053013553853497655                        NaN     creed   28.31
# ...

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0               event_time event_type    product_id  \
# count   1.000000e+07                 10000000   10000000  1.000000e+07
# unique           NaN                   523423          3           NaN
# top              NaN  2019-11-05 17:23:19 UTC       view           NaN
# freq             NaN                      113    9731128           NaN
# mean    5.000000e+06                      NaN        NaN  1.100008e+07
# std     2.886751e+06                      NaN        NaN  1.228346e+07
# min     0.000000e+00                      NaN        NaN  1.000365e+06
# 25%     2.500000e+06                      NaN        NaN  1.005252e+06
# 50%     5.000000e+06                      NaN        NaN  5.100722e+06
# 75%     7.499999e+06                      NaN        NaN  1.640001e+07
# max     9.999999e+06                      NaN        NaN  6.210003e+07
#
#          category_id           category_code    brand         price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Unnamed: 0     int64
#  1   event_time     object
#  2   event_type     object
#  3   product_id     int64
#  4   category_id    int64
#  5   category_code  object
#  6   brand          object
#  7   price          float64
#  8   user_id        int64
#  9   user_session   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 762.9+ MB

# %%
df[df['price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, event_time, event_type, product_id, category_id, category_code, brand, price, user_id, user_session]
# Index: []

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0               event_time event_type    product_id  \
# count   1.000000e+07                 10000000   10000000  1.000000e+07
# unique           NaN                   523423          3           NaN
# top              NaN  2019-11-05 17:23:19 UTC       view           NaN
# freq             NaN                      113    9731128           NaN
# mean    5.000000e+06                      NaN        NaN  1.100008e+07
# std     2.886751e+06                      NaN        NaN  1.228346e+07
# min     0.000000e+00                      NaN        NaN  1.000365e+06
# 25%     2.500000e+06                      NaN        NaN  1.005252e+06
# 50%     5.000000e+06                      NaN        NaN  5.100722e+06
# 75%     7.499999e+06                      NaN        NaN  1.640001e+07
# max     9.999999e+06                      NaN        NaN  6.210003e+07
#
#          category_id           category_code    brand         price  \
# ...

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: >

# %%
# when is the most products baught
# if an expensive product is baought it is baught at the same time
# dettermine the number of varients
# design an experiment
import matplotlib.pyplot as plt

# %%
dfr = df.groupby('category_code')['price'].sum().reset_index()
dfr.sort_values('price', axis=0, ascending=True, inplace=True)
dfr=dfr.drop(dfr[dfr['price']==0].index,axis=0)

fig, ax = plt.subplots(figsize=(5, 30))
sns.barplot(data=dfr, x='price', y='category_code')
# Out:
# <Axes: xlabel='price', ylabel='category_code'>

# %%
# electronics.smartphone should be catigorised with time of purchase


df['event_time'] = pd.to_datetime(df['event_time'], format='%Y-%m-%d %H:%M:%S %Z')
df['date'] = df['event_time'].dt.date
df['time'] = df['event_time'].dt.time

# %%
df.describe(include='all')
# Out:
# C:\Users\srika\AppData\Local\Temp\ipykernel_13292\2884002236.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#           Unnamed: 0                 event_time event_type    product_id  \
# count   1.000000e+07                   10000000   10000000  1.000000e+07
# unique           NaN                     523423          3           NaN
# top              NaN  2019-11-05 17:23:19+00:00       view           NaN
# freq             NaN                        113    9731128           NaN
# first            NaN  2019-11-01 00:00:00+00:00        NaN           NaN
# last             NaN  2019-11-07 05:08:21+00:00        NaN           NaN
# mean    5.000000e+06                        NaN        NaN  1.100008e+07
# ...

# %%
# understanding event_type
df_1 = df.groupby(['product_id','event_type'])['event_time'].count().unstack()
df_1
# Out:
# event_type  cart  purchase   view
# product_id
# 1000365      NaN       NaN    1.0
# 1000978      NaN       2.0  842.0
# 1001588      NaN       1.0  416.0
# 1001606      NaN       NaN    1.0
# 1002042      NaN       NaN    9.0
# ...          ...       ...    ...
# 62100027     NaN       NaN    2.0
# 62100028     NaN       NaN    1.0
# 62100029     NaN       NaN    7.0
# 62100030     NaN       NaN    1.0
# 62100031     NaN       NaN    1.0
#
# [133917 rows x 3 columns]

# %%
# df_2 = df.drop(df[df['category_code']=='electronics.smartphone'].index)

# %%
sns.boxplot(data=df[df['category_code']=='electronics.smartphone'],y='date',x='price')
# Out:
# <Axes: xlabel='price', ylabel='date'>

# %%
sns.boxplot(data=df[df['category_code']=='computers.notebook'],y='date',x='price')
# Out:
# <Axes: xlabel='price', ylabel='date'>

# %%
df=df.drop(df[df['price']==0].index)
df.sort_values('price',axis=0, ascending=True)
fig, ax = plt.subplots(figsize=(5, 30))
sns.barplot(data=df, x='price', y='category_code')

# %%
dk=df[df['category_code']=='electronics.camera.photo']
dfs=dk.groupby('brand').count()
sns.boxplot(data=dk,x='price',y='brand')
# Out:
# <Axes: xlabel='price', ylabel='brand'>

# %%
dfs
# Out:
#            Unnamed: 0  event_time  event_type  product_id  category_id  \
# brand
# canon            1418        1418        1418        1418         1418
# nikon             892         892         892         892          892
# olympus             4           4           4           4            4
# panasonic          24          24          24          24           24
# sigma              15          15          15          15           15
# sony              972         972         972         972          972
#
#            category_code  price  user_id  user_session  date  time
# brand
# canon               1418   1418     1418          1418  1418  1418
# nikon                892    892      892           892   892   892
# olympus                4      4        4             4     4     4
# panasonic             24     24       24            24    24    24
# sigma                 15     15       15            15    15    15
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                event_time event_type  product_id  \
# 0           0 2019-11-01 00:00:00+00:00       view     1003461
# 1           1 2019-11-01 00:00:00+00:00       view     5000088
# 2           2 2019-11-01 00:00:01+00:00       view    17302664
# 3           3 2019-11-01 00:00:01+00:00       view     3601530
# 4           4 2019-11-01 00:00:01+00:00       view     1004775
#
#            category_id              category_code   brand   price    user_id  \
# 0  2053013555631882655     electronics.smartphone  xiaomi  489.07  520088904
# 1  2053013566100866035  appliances.sewing_machine  janome  293.65  530496790
# 2  2053013553853497655                        NaN   creed   28.31  561587266
# 3  2053013563810775923  appliances.kitchen.washer      lg  712.87  518085591
# 4  2053013555631882655     electronics.smartphone  xiaomi  183.27  558856683
#
#                            user_session        date      time
# ...

# %%
# sns.boxplot(data=df[df['category_code']=='electronics.smartphone'],y='time',x='price')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 sns.boxplot(data=df[df['category_code']=='electronics.smartphone'],y='time',x='price')
#
# File c:\Users\srika\anaconda3\lib\site-packages\seaborn\categorical.py:2239, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2236     ax = plt.gca()
#    2237 kwargs.update(dict(whis=whis))
# -> 2239 plotter.plot(ax, kwargs)
#    2240 return ax
#
# File c:\Users\srika\anaconda3\lib\site-packages\seaborn\categorical.py:888, in _BoxPlotter.plot(self, ax, boxplot_kws)
#     886 def plot(self, ax, boxplot_kws):
#     887     """Make the plot."""
# --> 888     self.draw_boxplot(ax, boxplot_kws)
#     889     self.annotate_axes(ax)
#     890     if self.orient == "h":
#
# ...

# %%
# sns.pairplot(df)
